# %% [markdown]
# # Jupyter Notebook for Combining Location and WiFi Data
#
# The purpose of this notebook is just to combine the location and WiFi data. It was primarily used for debugging to make sure things were properly being formatted.

# %%
import datamanager
import pandas as pd
import os
import numpy as np
pd.set_option('display.max_rows', None)

# %%
zone = 'reid-2'
result = datamanager.combine_data(zone)
result
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-94798a5027bf> in <module>
#       1 zone = 'reid-2'
# ----> 2 result = datamanager.combine_data(zone)
#       3 result
#
# ~\Desktop\UWA\PG\Wireless Computing\uwa_wifi_scan\datamanager.py in combine_data(zone, coords_file)
#      21             A dataframe with the data combined
#      22     """
# ---> 23     locations = pd.read_excel(os.path.join(COORDS_DIR, coords_file),
#      24                                 sheet_name=zone,
#      25                                 usecols=["lat", "lon"]).to_numpy()
#
# c:\users\akhil naseem\anaconda3\envs\wifi_scan\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
# ...

# %%
datamanager.save_wifi_loc_data(result, zone)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c98067eca75c> in <module>
# ----> 1 datamanager.save_wifi_loc_data(result, zone)
#
# NameError: name 'result' is not defined

# %%
datamanager.load_wifi_at_location('james')
# Out:
#      index        lat         lon               time              bssid  \
# 0        0 -31.981019  115.817290  20-09-15-15-54-31  A0:CF:5B:3C:35:9F
# 1        1 -31.981019  115.817290  20-09-15-15-54-31  A0:CF:5B:3C:35:90
# 2        2 -31.981019  115.817290  20-09-15-15-54-31  7C:21:0E:3E:6A:6F
# 3        3 -31.981019  115.817290  20-09-15-15-54-31  A0:CF:5B:3C:2E:B0
# 4        4 -31.981019  115.817343  20-09-15-15-54-42  A0:CF:5B:3C:35:9F
# 5        5 -31.981019  115.817343  20-09-15-15-54-42  A0:CF:5B:3C:35:90
# 6        6 -31.981019  115.817343  20-09-15-15-54-42  7C:21:0E:3E:6A:6F
# 7        7 -31.981019  115.817343  20-09-15-15-54-42  A0:CF:5B:3C:2E:B0
# 8        8 -31.981019  115.817343  20-09-15-15-54-42  10:BD:18:C7:27:7F
# 9        9 -31.981019  115.817343  20-09-15-15-54-42  10:BD:18:C6:D6:7F
# 10      10 -31.981019  115.817343  20-09-15-15-54-42  10:BD:18:C7:27:70
# 11      11 -31.981019  115.817343  20-09-15-15-54-42  A0:CF:5B:3E:26:F0
# ...
